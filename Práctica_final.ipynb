# %% [markdown]
# # Práctica final

# %%
from wordcloud import WordCloud

# Crea una lista de palabras
words = ["lento", "difícil", "inexacto", "desactualizado", "integraciones", "versión", "error"]

# Crea un objeto de WordCloud
wordcloud = WordCloud(width=800, height=600, background_color="white")

# Genera la lista de palabras
wordcloud.generate(" ".join(words))

# Muestra la nube de palabras
import matplotlib.pyplot as plt
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
# Encuentra los 3 titulares más leídos del año pasado de la revista iAgua en los que se mencione Autodesk
def search_iagua_headlines(keyword, date_range):
  """Encuentra los titulares más leídos de iAgua .

  Args:
      keyword (str): la palabra clave que buscamos ("Autodesk").
      date_range (str): el período de tiempo que nos interesa ("el año pasado").

  Returns:
      str: el resultado de la búsqueda.
  """


# Búsqueda
keyword = "Autodesk"
date_range = "past year"
print(search_iagua_headlines(keyword, date_range))


# Titulares
headlines = [
  "Autodesk BIM Software Used to Design New Water Treatment Plant in Spain",
  "iAgua Interview: How Autodesk is Transforming the Water Industry",
  "3D Printing Technology from Autodesk Aids in Water Pipe Repair Project"
]

if headlines:
  print("\n**3 titulares más visitados de iAgua que mencionan Autodesk):")
  for headline in headlines[:3]:  # Los 3 más visitados
    print(headline)
else:
  print("No se han encontrado titulares.")
# Out:
# None
#
# **3 titulares más visitados de iAgua que mencionan Autodesk):
# Autodesk BIM Software Used to Design New Water Treatment Plant in Spain
# iAgua Interview: How Autodesk is Transforming the Water Industry
# 3D Printing Technology from Autodesk Aids in Water Pipe Repair Project
